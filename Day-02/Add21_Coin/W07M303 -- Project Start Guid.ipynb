# %%
# Project.Step1/5 - Detect Object
import cv2
import numpy as np

cap = cv2.VideoCapture('./image/Save2.avi')
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        if circles is not None:
            circles = np.uint16(np.around(circles))
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)

        # Show Result and Wait Exit
        cv2.imshow('Output-Frame',belt)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture('./image/Save2.avi')
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        if circles is not None:
            circles = np.uint16(np.around(circles))
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)

        # Show Result and Wait Exit
        cv2.imshow('Output-Frame',belt)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# Project.Step2/5 - Detect Object + Draw Ref Line
import cv2
import numpy as np

cap = cv2.VideoCapture('./image/Save2.avi')
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        # Show Result and Wait Exit
        W,H,C = belt.shape
        HRef = int(H*0.97)
        cv2.line(belt,(0,HRef),(W,HRef),(255,0,0),2)
        
        if circles is not None:
            circles = np.uint16(np.around(circles))
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)
    
        # Show Result and Wait Exit
        cv2.imshow('Output-Frame',belt)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# Project.Step3/5 - Detect Object + Draw Ref Line + Put Text
import cv2
import numpy as np

cap = cv2.VideoCapture('./image/Save2.avi')
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        # Show Result and Wait Exit
        W,H,C = belt.shape
        HRef = int(H*0.97)
        cv2.line(belt,(0,HRef),(W,HRef),(255,0,0),2)
        
        if circles is not None:
            circles = np.uint16(np.around(circles))
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)

        # Put Text
        nCounter = 1234
        cv2.putText(belt,"n="+str(nCounter),(5,80),cv2.FONT_HERSHEY_SIMPLEX,2,(0,0,255),2,cv2.LINE_AA)
        
        # Show Result and Wait Exit
        cv2.imshow('Output-Frame',belt)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# Project.Step4/5 - Detect Object + Draw Ref Line + Put Text + Count(Level)
import cv2
import numpy as np
nCounter = 0
frameCount = 1234

cap = cv2.VideoCapture('./image/Save2.avi')
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        # Show Result and Wait Exit
        W,H,C = belt.shape
        HRef = int(H*0.97)
        cv2.line(belt,(0,HRef),(W,HRef),(255,0,0),2)
        
        frameCount = frameCount + 1
        if circles is not None:
            circles = np.uint16(np.around(circles))
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)
                
                if (((i[1])+i[2]) > HRef) and (frameCount > 20):
                    nCounter = nCounter + 1
                    frameCount = 0
            
        # Put Text
        cv2.putText(belt,"n="+str(nCounter),(5,80),cv2.FONT_HERSHEY_SIMPLEX,2,(0,0,255),2,cv2.LINE_AA)
        
        # Show Result and Wait Exit
        cv2.imshow('Output-Frame',belt)
        if cv2.waitKey(100) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# Project.Step5/5 - Detect Object + Draw Ref Line + Put Text + Count(Edge)
import cv2
import numpy as np
nCounter = 0
 
cap = cv2.VideoCapture('./image/Save2.avi')
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        # Show Result and Wait Exit
        W,H,C = belt.shape
        LineInRef  = int(H*0.87)
        LineOutRef = int(H*0.97)
        cv2.line(belt,(0,LineInRef),(W,LineInRef),(255,192,203),2)
        cv2.line(belt,(0,LineOutRef),(W,LineOutRef),(255,0,0),2)
        
        frameCount = frameCount + 1
        if circles is not None:
            circles = np.uint16(np.around(circles))
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)
                
                if (((i[1])+i[2]) > LineInRef) : 
                    stsLine_In = 1
                else:
                    stsLine_In = 0
                
                if (((i[1])+i[2]) > LineOutRef) :
                    stsLine_Out = 1
                else:
                    stsLine_Out = 0                   
                    
                if(stsLine_Out==0 and stsLine_In==0):
                     stsCount = 0
                        
                if(stsLine_Out==1 and stsLine_In==1 and stsCount == 0):
                    nCounter = nCounter + 1
                    stsCount = 1
                
        # Put Text
        cv2.putText(belt,"n="+str(nCounter),(5,80),cv2.FONT_HERSHEY_SIMPLEX,2,(0,0,255),2,cv2.LINE_AA)
        
        # Show Result and Wait Exit
        cv2.imshow('Output-Frame',belt)
        if cv2.waitKey(100) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# Project.Step1b/4 - Detect Object with pause
import cv2
import time
import numpy as np

points=[]
layer = 0

def onMouse(event, x, y, flags, param):
    if len(points) < 2:
        if event == cv2.EVENT_LBUTTONDOWN:
            points.append((x,y))
            print(points)
            
cap = cv2.VideoCapture('./image/save2.avi')
while cap.isOpened():
    layer +=1
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        if circles is not None:
            circles = np.uint16(np.around(circles))
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)

        # Show Result and Wait Exit
        cv2.imshow('Output-Frame',belt)
    
        # wait click    
        key = cv2.waitKey(100)

        #if len(points) < 2 and layer==2:
        #    cv2.setMouseCallback(win, onMouse)        
        
        if key == ord("q"):
            break
    
cap.release()
cv2.destroyAllWindows()

# %%
# Project.Step2/4 - Reference line and putText

# %%
# Project.Step3/4 - Segmentation

# %%
# Project.Step4/4 - Segmentation and Count
