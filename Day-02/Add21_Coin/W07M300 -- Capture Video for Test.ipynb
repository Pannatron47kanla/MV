# %%
# Prepair.1/4 -- Open Camera
import cv2
cap = cv2.VideoCapture(0)
while(True):
    ret, frame = cap.read()
    if ret == False:
        print("Camera not found")
        break
    else:
        # gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        # cv2.imshow('frame',gray)
        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# Prepair.2/4 -- Find roi
import cv2 
img_Name = 'Get Point'

def click_event(event, x, y, flags, param): 
    if event == cv2.EVENT_LBUTTONDOWN:
        refpt = []                      # ตัวแปร
        refpt.append([x,y])             # เพิ่มข้อมูลเข้าไปในตัวแปร
        print(x,y)
        font = cv2.FONT_HERSHEY_SIMPLEX # font = แบบตัวอักษร
        cv2.putText(img, str(x) + "," + str(y),(x,y), font, 0.5, (255,255,0), 2) 
        cv2.imshow(img_Name, img)       # putText > แสดงตัวอักษรบนหน้าต่างแสดงรูป
        
cap = cv2.VideoCapture(2)
ret, img = cap.read()
cv2.imshow(img_Name, img) 
cv2.setMouseCallback(img_Name, click_event) 

cv2.waitKey(0) 
cap.release()
cv2.destroyAllWindows()

# %%
# Prepair.3/4 -- WebCam to Video
import cv2
video = cv2.VideoCapture(0)
if (video.isOpened() == False):
    print("Error reading video file")

frame_height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT)) 
frame_width  = int(video.get(cv2.CAP_PROP_FRAME_WIDTH)) 
frame_fps = int(video.get(cv2.CAP_PROP_FPS)) 
print(frame_width, frame_height,frame_fps)

result = cv2.VideoWriter('./image/Save8.mp4',
                         cv2.VideoWriter_fourcc(*'DIVX'),
                         frame_fps, (frame_width, frame_height))

while(True):
    ret, frame = video.read()
    if ret == True:
        result.write(frame)
        cv2.imshow('Frame', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

video.release()
result.release()
cv2.destroyAllWindows()
print("The video was successfully saved")
# Out:
# 640 480 30
# The video was successfully saved

# %%
# Prepair.4/4 -- Open Video
import cv2

cap = cv2.VideoCapture('./image/Save8.mp4')
while(True):
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        cv2.imshow('frame',frame)
        #cv2.imshow('frame',gray)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()          
cv2.destroyAllWindows()
