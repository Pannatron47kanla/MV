# %%
# Project.Step1/6 - Detect Object
import cv2
import numpy as np

cap = cv2.VideoCapture('./image/Save2.avi')
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        if circles is not None:
            circles = np.uint16(np.around(circles))
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)

        # Show Result and Wait Exit
        cv2.imshow('Output-Frame',belt)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# Project.Step2/6 - Detect Object + Group with Countour
import cv2
import numpy as np

def SummCircle(imgIn, iCircles):
    imgIn = imgIn*0
    for i in iCircles[0,:]:
        cv2.circle(imgIn,(i[0],i[1]),i[2],(255,255,255),-1)
    img_gray = cv2.cvtColor(imgIn, cv2.COLOR_BGR2GRAY)
    ret, im = cv2.threshold(img_gray, 100, 255, cv2.THRESH_BINARY)
    contours, hierarchy = cv2.findContours(im, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    imgIn = cv2.drawContours(imgIn, contours, -1, (75,255,0), 2)
    
    GSquare = []
    for contour in contours:
        [x,y,w,h] = cv2.boundingRect(contour)
        cv2.rectangle(imgIn,(x,y),(x+w,y+h),(255,255,0),2)
        GSquare.append([x,y,w,h])
        
    cv2.imshow('Frame-Temp',imgIn)
    return GSquare
    
    
cap = cv2.VideoCapture('./image/Save2.avi')
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        if circles is not None:
            circles = np.uint16(np.around(circles))
            squares = SummCircle(belt.copy(),circles)
            
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)
            for i in squares:
                cv2.rectangle(belt,(i[0],i[1]),(i[0]+i[2],i[1]+i[3]),(0xaa,0x46,0xfc),2)  
        
        # Show Result and Wait Exit
        cv2.imshow('Output-Frame',belt)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# Project.Step3/6 - Detect Object + Group with Countour + Draw Ref line
import cv2
import numpy as np

def SummCircle(imgIn, iCircles):
    imgIn = imgIn*0
    for i in iCircles[0,:]:
        cv2.circle(imgIn,(i[0],i[1]),i[2],(255,255,255),-1)
    img_gray = cv2.cvtColor(imgIn, cv2.COLOR_BGR2GRAY)
    ret, im = cv2.threshold(img_gray, 100, 255, cv2.THRESH_BINARY)
    contours, hierarchy = cv2.findContours(im, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    imgIn = cv2.drawContours(imgIn, contours, -1, (75,255,0), 2)
    
    GSquare = []
    for contour in contours:
        [x,y,w,h] = cv2.boundingRect(contour)
        cv2.rectangle(imgIn,(x,y),(x+w,y+h),(255,255,0),2)
        GSquare.append([x,y,w,h])
        
    cv2.imshow('Frame-Temp',imgIn)
    return GSquare
    
    
cap = cv2.VideoCapture('./image/Save2.avi')
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Draw Ref-line
        W,H,C = belt.shape
        HRef = int(H*0.97)
        cv2.line(belt,(0,HRef),(W,HRef),(255,0,0),2)

        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        if circles is not None:
            circles = np.uint16(np.around(circles))
            squares = SummCircle(belt.copy(),circles)
            
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)
            for i in squares:
                cv2.rectangle(belt,(i[0],i[1]),(i[0]+i[2],i[1]+i[3]),(0xaa,0x46,0xfc),2)  

        # Show Result and Wait Exit
        cv2.imshow('Output-Frame',belt)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# Project.Step4/6 - Detect Object + Group with Countour + Draw Ref line + putText
import cv2
import numpy as np
nCounter = 1234

def SummCircle(imgIn, iCircles):
    imgIn = imgIn*0
    for i in iCircles[0,:]:
        cv2.circle(imgIn,(i[0],i[1]),i[2],(255,255,255),-1)
    img_gray = cv2.cvtColor(imgIn, cv2.COLOR_BGR2GRAY)
    ret, im = cv2.threshold(img_gray, 100, 255, cv2.THRESH_BINARY)
    contours, hierarchy = cv2.findContours(im, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    imgIn = cv2.drawContours(imgIn, contours, -1, (75,255,0), 2)
    
    GSquare = []
    for contour in contours:
        [x,y,w,h] = cv2.boundingRect(contour)
        cv2.rectangle(imgIn,(x,y),(x+w,y+h),(255,255,0),2)
        GSquare.append([x,y,w,h])
        
    cv2.imshow('Frame-Temp',imgIn)
    return GSquare
    
cap = cv2.VideoCapture('./image/Save2.avi')
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Draw Ref-line
        W,H,C = belt.shape
        HRef = int(H*0.97)
        cv2.line(belt,(0,HRef),(W,HRef),(255,0,0),2)

        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        if circles is not None:
            circles = np.uint16(np.around(circles))
            squares = SummCircle(belt.copy(),circles)
            
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)
            for i in squares:
                cv2.rectangle(belt,(i[0],i[1]),(i[0]+i[2],i[1]+i[3]),(0xaa,0x46,0xfc),2)  
        
        # Put Text
        cv2.putText(belt,"n="+str(nCounter),(5,80),cv2.FONT_HERSHEY_SIMPLEX,2,(0,0,255),2,cv2.LINE_AA)

        # Show Result and Wait Exit
        cv2.imshow('Output-Frame',belt)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# Project.Step5/6 - Detect Object + Group with Countour + Draw Ref line + putText + level Count
import cv2
import numpy as np
nCounter = 0
frameCount, delayFrame = 1234, 10

def SummCircle(imgIn, iCircles):
    imgIn = imgIn*0
    for i in iCircles[0,:]:
        cv2.circle(imgIn,(i[0],i[1]),i[2],(255,255,255),-1)
    img_gray = cv2.cvtColor(imgIn, cv2.COLOR_BGR2GRAY)
    ret, im = cv2.threshold(img_gray, 100, 255, cv2.THRESH_BINARY)
    contours, hierarchy = cv2.findContours(im, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    imgIn = cv2.drawContours(imgIn, contours, -1, (75,255,0), 2)
    
    GSquare = []
    for contour in contours:
        [x,y,w,h] = cv2.boundingRect(contour)
        cv2.rectangle(imgIn,(x,y),(x+w,y+h),(255,255,0),2)
        GSquare.append([x,y,w,h])
        
    cv2.imshow('Frame-Temp',imgIn)
    return GSquare 
    
cap = cv2.VideoCapture('./image/Save2.avi')
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Draw Ref-line
        W,H,C = belt.shape
        HRef = int(H*0.97)
        cv2.line(belt,(0,HRef),(W,HRef),(255,0,0),2)
   
        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        frameCount = frameCount + 1
        if circles is not None:
            circles = np.uint16(np.around(circles))
            squares = SummCircle(belt.copy(),circles)
            
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)
            for i in squares:
                [x,y,w,h] = i
                cv2.rectangle(belt,(x,y),(x+w,y+h),(0xaa,0x46,0xfc),2)  
        
            if ((y+h) > HRef) and (frameCount > delayFrame):
                nCounter = nCounter + 1
                frameCount = 0
        
        # Put Text
        cv2.putText(belt,"n="+str(nCounter),(5,80),cv2.FONT_HERSHEY_SIMPLEX,2,(0,0,255),2,cv2.LINE_AA)

        # Show Result and Wait Exit
        cv2.imshow('Output-Frame',belt)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
print("nCounter = ",nCounter)
# Out:
# nCounter =  43

# %%
# Project.Step5/6 - Detect Object + Group with Countour + Draw Ref line + putText + Edge Count
import cv2
import numpy as np
nCounter = 0
frameCount, delayFrame = 1234, 10

def SummCircle(imgIn, iCircles):
    imgIn = imgIn*0
    for i in iCircles[0,:]:
        cv2.circle(imgIn,(i[0],i[1]),i[2],(255,255,255),-1)
    img_gray = cv2.cvtColor(imgIn, cv2.COLOR_BGR2GRAY)
    ret, im = cv2.threshold(img_gray, 100, 255, cv2.THRESH_BINARY)
    contours, hierarchy = cv2.findContours(im, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    imgIn = cv2.drawContours(imgIn, contours, -1, (75,255,0), 2)
    
    GSquare = []
    for contour in contours:
        [x,y,w,h] = cv2.boundingRect(contour)
        cv2.rectangle(imgIn,(x,y),(x+w,y+h),(255,255,0),2)
        GSquare.append([x,y,w,h])
        
    cv2.imshow('Frame-Temp',imgIn)
    return GSquare
     
cap = cv2.VideoCapture('./image/Save2.avi')
while cap.isOpened():
    ret, frame = cap.read()
    if frame is None:
        break
    else:
        # Cut the Area, Blur, Chage to Gray  
        belt = frame[50: 475, 80: 400]  
        belt = cv2.medianBlur(belt,5)
        gray_belt = cv2.cvtColor(belt, cv2.COLOR_BGR2GRAY)
        cv2.imshow('Frame-Input',belt)

        # Threshold Operation
        _, threshold = cv2.threshold(gray_belt,80,255,cv2.THRESH_BINARY)
        cv2.imshow('Frame-Threshold',threshold)

        # Draw Ref-line
        W,H,C = belt.shape
        LineInRef  = int(H*0.87)
        LineOutRef = int(H*0.97)
        cv2.line(belt,(0,LineInRef),(W,LineInRef),(255,192,203),2)
        cv2.line(belt,(0,LineOutRef),(W,LineOutRef),(255,0,0),2)
   
        # Mask Circle and Draw 
        circles = cv2.HoughCircles(threshold, cv2.HOUGH_GRADIENT, 1, 20,
                                   param1=50, param2=30, minRadius=30, maxRadius=80)
        
        frameCount = frameCount + 1
        if circles is not None:
            circles = np.uint16(np.around(circles))
            squares = SummCircle(belt.copy(),circles)
            
            for i in circles[0,:]:
                cv2.circle(belt,(i[0],i[1]),i[2],(0,255,0),2)
            for i in squares:
                [x,y,w,h] = i
                cv2.rectangle(belt,(x,y),(x+w,y+h),(0xaa,0x46,0xfc),2)  
        
                if (y+h) > LineInRef :
                    stsLine_In = 1
                else:
                    stsLine_In = 0
                
                if (y+h) > LineOutRef :
                    stsLine_Out = 1
                else:
                    stsLine_Out = 0                   
                    
                if(stsLine_Out==0 and stsLine_In==0):
                    stsCount = 1
                        
                if(stsLine_Out==1 and stsLine_In==1 and frameCount > delayFrame):
                    nCounter = nCounter + stsCount
                    frameCount = 0
                    stsCount = 0

        
        # Put Text
        cv2.putText(belt,"n="+str(nCounter),(5,80),cv2.FONT_HERSHEY_SIMPLEX,2,(0,0,255),2,cv2.LINE_AA)

        # Show Result and Wait Exit
        dddd = nCounter < 150 and 1 or 100
        cv2.imshow('Output-Frame',belt)
        if cv2.waitKey(dddd) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
print("nCounter = ",nCounter)
# Out:
# nCounter =  44
